# %%
# Import packages
import os
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import seaborn as sns
from sklearn.decomposition import PCA
from pandas.api.types import CategoricalDtype
from sklearn.preprocessing import MinMaxScaler
# %matplotlib inline

# %%
from sklearn.cluster import KMeans

# %%
# Load the dataset
data_path = os.path.join(os.getcwd(), 'Spotify_Dataset_V3.csv')
df = pd.read_csv(data_path, delimiter=';')
df["Date"] = pd.to_datetime(df["Date"], format="%d/%m/%Y")
df["Day_in_week"] = df["Date"].dt.day_name()
df["Month"] = df["Date"].dt.month
df.head()
# Out:
#    Rank            Title                     Artists       Date  Danceability  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-29         0.668
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma 2023-05-29         0.668
# 2     2   WHERE SHE GOES                   Bad Bunny 2023-05-29         0.652
# 3     3  La Bebe - Remix       Yng Lvcas, Peso Pluma 2023-05-29         0.812
# 4     3  La Bebe - Remix       Yng Lvcas, Peso Pluma 2023-05-29         0.812
#
#    Energy  Loudness  Speechiness  Acousticness  Instrumentalness  ...  \
# 0   0.758   -5176.0        0.033         0.483             0.000  ...
# 1   0.758   -5176.0        0.033         0.483             0.000  ...
# 2   0.800   -4019.0        0.061         0.143             0.629  ...
# 3   0.479   -5678.0        0.333         0.213             0.000  ...
# 4   0.479   -5678.0        0.333         0.213             0.000  ...
#
#     Artist (Ind.) # of Nationality  Nationality      Continent Points (Total)  \
# 0  Eslabon Armado    Nationality 1       Mexico  Latin-America            200
# 1      Peso Pluma    Nationality 2       Mexico  Latin-America            200
# 2       Bad Bunny    Nationality 1  Puerto Rico  Latin-America            199
# 3       Yng Lvcas    Nationality 1       Mexico  Latin-America            198
# 4      Peso Pluma    Nationality 2       Mexico  Latin-America            198
#
#   Points (Ind for each Artist/Nat)                      id  \
# 0                            100.0  3qQbCzHBycnDpGskqOWY0E
# 1                            100.0  3qQbCzHBycnDpGskqOWY0E
# 2                            199.0  7ro0hRteUMfnOioTFI5TG1
# 3                             99.0  2UW7JaomAMuX9pZrjVpHAU
# 4                             99.0  2UW7JaomAMuX9pZrjVpHAU
#
#                                             Song URL Day_in_week Month
# 0  https://open.spotify.com/track/3qQbCzHBycnDpGs...      Monday     5
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...      Monday     5
# 2  https://open.spotify.com/track/7ro0hRteUMfnOio...      Monday     5
# 3  https://open.spotify.com/track/2UW7JaomAMuX9pZ...      Monday     5
# 4  https://open.spotify.com/track/2UW7JaomAMuX9pZ...      Monday     5
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Data visualisation

# %%
df_features = df[['Danceability', 'Energy', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Valence', 'Loudness', 'Month', 'Day_in_week', 'Points (Total)']].copy()
df_main_features = df_features.drop(columns=['Month', 'Day_in_week', 'Points (Total)']).copy()
df_main_features.describe()
# Out:
#         Danceability         Energy    Speechiness   Acousticness  \
# count  651936.000000  651936.000000  651936.000000  651936.000000
# mean        0.697730       0.652049       0.109946       0.230694
# std         0.133186       0.155684       0.096841       0.230710
# min         0.073000       0.005000       0.022000       0.000000
# 25%         0.617000       0.549000       0.045000       0.048000
# 50%         0.719000       0.671000       0.068000       0.152000
# 75%         0.793000       0.771000       0.136000       0.349000
# max         0.985000       0.996000       0.966000       0.994000
#
#        Instrumentalness        Valence       Loudness
# count     651936.000000  651936.000000  651936.000000
# mean           0.007647       0.523134   -5295.645217
# std            0.054724       0.223926    2785.261321
# min            0.000000       0.026000  -34475.000000
# 25%            0.000000       0.356000   -6825.000000
# 50%            0.000000       0.521000   -5206.000000
# 75%            0.000000       0.696000   -3885.000000
# max            0.956000       0.982000    1509.000000

# %%
plt.figure(figsize=(10, 10))
plt.subplot(211)
sns.boxenplot(df_main_features.drop(columns="Loudness"), orient="y")

plt.subplot(212)
sns.boxenplot(df["Loudness"],orient="y")
# Out:
# <Axes: >

# %%
def plotManyHist(df):
    for i in range(len(df.columns)):
        plt.figure(figsize=(15, 4))
        feature = df.columns[i]
        sns.histplot(data=df[feature], bins=100)
        plt.show()

# %%
plotManyHist(df_main_features)

# %% [markdown]
# ## Data Cleaning

# %%
df_features[df_features["Loudness"] > -1000]["Loudness"].min()
# Out:
# -31.16

# %%
# 1. Remove Loundness that values higher that -1000
loundness_outlier_mask = df_main_features["Loudness"] > -1000
df_features_clean_loudness = df_main_features[~loundness_outlier_mask].copy()

# %%
df_features_clean_loudness
# Out:
#         Danceability  Energy  Speechiness  Acousticness  Instrumentalness  \
# 0              0.668   0.758        0.033         0.483             0.000
# 1              0.668   0.758        0.033         0.483             0.000
# 2              0.652   0.800        0.061         0.143             0.629
# 3              0.812   0.479        0.333         0.213             0.000
# 4              0.812   0.479        0.333         0.213             0.000
# ...              ...     ...          ...           ...               ...
# 651931         0.273   0.794        0.068         0.022             0.000
# 651932         0.650   0.658        0.085         0.089             0.004
# 651933         0.665   0.771        0.053         0.016             0.000
# 651934         0.757   0.882        0.248         0.076             0.000
# 651935         0.757   0.882        0.248         0.076             0.000
#
#         Valence  Loudness
# 0         0.834   -5176.0
# 1         0.834   -5176.0
# 2         0.234   -4019.0
# 3         0.559   -5678.0
# 4         0.559   -5678.0
# ...         ...       ...
# 651931    0.377   -6644.0
# 651932    0.883  -10908.0
# 651933    0.764   -5779.0
# 651934    0.684   -6125.0
# 651935    0.684   -6125.0
#
# [587116 rows x 7 columns]

# %%
# 2. Remove outliers using IQR, outliers = out of this range [Q1-1.5IQR, Q3+1.5IQR]
# lower_quantile = 0.25
# upper_quantile = 0.75

# lower_bounds = df_features_clean_loudness.quantile(lower_quantile)
# upper_bounds = df_features_clean_loudness.quantile(upper_quantile)
# iqr15 = (upper_bounds - lower_bounds) * 1.5

# outliers = ((df_features_clean_loudness < (lower_bounds - iqr15)) | 
#             (df_features_clean_loudness > (upper_bounds + iqr15))).any(axis=1)
# df_clean = (df_features[~loundness_outlier_mask])[~outliers].copy()
df_clean = df_features[~loundness_outlier_mask].copy()
df_clean.describe()
# Out:
#         Danceability         Energy    Speechiness   Acousticness  \
# count  587116.000000  587116.000000  587116.000000  587116.000000
# mean        0.696675       0.651695       0.109087       0.231386
# std         0.133315       0.155240       0.097033       0.231352
# min         0.073000       0.005000       0.022000       0.000000
# 25%         0.617000       0.550000       0.044000       0.049000
# 50%         0.715000       0.670000       0.067000       0.153000
# 75%         0.791000       0.770000       0.135000       0.348000
# max         0.985000       0.996000       0.966000       0.994000
#
#        Instrumentalness        Valence       Loudness          Month  \
# count     587116.000000  587116.000000  587116.000000  587116.000000
# mean           0.007677       0.524530   -5879.698574       6.274023
# std            0.054268       0.223258    2276.668001       3.474964
# min            0.000000       0.026000  -34475.000000       1.000000
# 25%            0.000000       0.357000   -7058.000000       3.000000
# 50%            0.000000       0.523000   -5515.000000       6.000000
# 75%            0.000000       0.697000   -4323.000000       9.000000
# max            0.956000       0.982000   -1167.000000      12.000000
#
#        Points (Total)
# count   587116.000000
# mean       100.594823
# std         57.462658
# min          1.000000
# 25%         51.000000
# 50%        101.000000
# 75%        150.000000
# max        200.000000

# %%
# 3. drop Instrumentalness?
# df_clean.drop(columns=['Instrumentalness'], inplace=True)

# %%
# 4. Normalize loudness?
# scaler = MinMaxScaler() 
# df_clean["Loudness"] = (df_clean["Loudness"]-df_clean["Loudness"].min())/df_clean["Loudness"].std()

# %%
print(df_features.shape, "->", df_clean.shape)
# Out:
# (651936, 10) -> (587116, 10)

# %% [markdown]
# ### - Visualise cleaned data

# %%
plotManyHist(df_clean.drop(columns=['Month', 'Day_in_week', 'Points (Total)']))

# %%
corr = df_clean.drop(columns=["Month", "Day_in_week"]).corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(6, 5))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
# may use "abs(corr)"
sns.heatmap((corr), mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .8})
# Out:
# <Axes: >

# %%
sns.scatterplot(data=df_clean, x="Loudness", y="Valence")
# Out:
# <Axes: xlabel='Loudness', ylabel='Valence'>

# %% [markdown]
# ### - Corr btw features & Points (Total) filtered by day in week

# %%
df_raw["Day_in_week"].unique()
# Out:
# array(['Monday', 'Sunday', 'Saturday', 'Friday', 'Thursday', 'Wednesday',
#        'Tuesday'], dtype=object)

# %%
df_raw = df_clean.drop(columns=["Month"]).copy()
df_corr_day = pd.DataFrame()

for day in ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']:
    df_corr = df_raw[df_raw["Day_in_week"] == day].drop(columns="Day_in_week").corr()
    df_corr_day[day] = df_corr[["Points (Total)"]].T.drop(columns="Points (Total)").iloc[0]

df_corr_day
# Out:
#                     Monday   Tuesday  Wednesday  Thursday    Friday  Saturday  \
# Danceability      0.041944  0.043813   0.045822  0.049787  0.038404  0.040653
# Energy            0.003624  0.004209   0.004467  0.003668 -0.006112 -0.005485
# Speechiness      -0.013767 -0.014924  -0.014907 -0.012586 -0.014506 -0.012385
# Acousticness     -0.012274 -0.012551  -0.010455 -0.009590 -0.005315 -0.009336
# Instrumentalness -0.030973 -0.028848  -0.028690 -0.029288 -0.024623 -0.027576
# Valence           0.017172  0.017201   0.016238  0.017141  0.006814  0.004630
# Loudness          0.028359  0.029518   0.032098  0.033070  0.018736  0.025742
#
#                     Sunday
# Danceability      0.039758
# Energy            0.002276
# Speechiness      -0.012880
# Acousticness     -0.014757
# Instrumentalness -0.023687
# Valence           0.005760
# Loudness          0.031499

# %%
# Draw the heatmap
f, ax = plt.subplots(figsize=(10, 8))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap((df_corr_day), cmap=cmap, center=0, square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.3f')

plt.xlabel("Point")
# Out:
# Text(0.5, 58.7222222222222, 'Point')

# %%
# fig, axes = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
# sns.heatmap(ax=axes[0], data=df_corr_day[["Monday"]], cmap=cmap, center=0, square=True,
#             linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.3f')
# sns.heatmap(ax=axes[1], data=df_corr_day[["Tuesday"]], cmap=cmap, center=0, square=True,
#             linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.3f')
# sns.heatmap(ax=axes[2], data=df_corr_day[["Wednesday"]], cmap=cmap, center=0, square=True,
#             linewidths=.5, cbar_kws={"shrink": .5}, annot=True, fmt='.3f')

# %% [markdown]
# # Export cleaned dataset to csv

# %%
df_clean.to_csv("cleaned_data.csv")

# %% [markdown]
# ## Clustering (Draft)

# %%
df_cluster_original = df_clean.drop(columns=["Day_in_week", "Month"]).copy()
# df_cluster_original = df_main_features.copy()

kmeans = KMeans(n_clusters=10, random_state=0, n_init="auto")
kmeans.fit(df_cluster_original)

df_cluster = df_cluster_original.copy()
df_cluster['cluster'] = kmeans.labels_
labels = kmeans.labels_

pca = PCA(n_components=4)  # Reduce to 2 dimensions
X_2d = pca.fit_transform(df_cluster_original)

plt.scatter(X_2d[:, 0], X_2d[:, 1], c=labels, cmap='viridis')

# %%
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')
ax.scatter(X_2d[:, 0], X_2d[:, 1], X_2d[:, 2], c=labels)
plt.show()

# %% [markdown]
# ## Explore data for each cluster

# %%
# Filter songs based on a specific cluster
pd.options.display.max_colwidth = 100
df.filter(items=df_cluster[df_cluster["cluster"] == 3].index, axis=0)
# Out:
#         Rank                             Title            Artists       Date  \
# 274      186                              I AM                IVE 2023-05-29
# 277      189           Shut up My Moms Calling         Hotel Ugly 2023-05-29
# 278      190                             Lover       Taylor Swift 2023-05-29
# 279      191                            Demons    Imagine Dragons 2023-05-29
# 280      192                           Shivers         Ed Sheeran 2023-05-29
# ...      ...                               ...                ...        ...
# 651929   195  Taped up Heart (feat. Clara Mae)              KREAM 2017-01-01
# 651930   196                     White Iverson        Post Malone 2017-01-01
# 651933   199                           Secrets         The Weeknd 2017-01-01
# 651934   200                   Ni**as In Paris  JAY-Z, Kanye West 2017-01-01
# 651935   200                   Ni**as In Paris  JAY-Z, Kanye West 2017-01-01
#
#         Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 274            0.683   0.875   -4866.0        0.055         0.012
# 277            0.485   0.409  -10711.0        0.101         0.325
# 278            0.359   0.543   -7582.0        0.092         0.492
# 279            0.505   0.710   -3015.0        0.032         0.190
# 280            0.788   0.859   -2724.0        0.086         0.281
# ...              ...     ...       ...          ...           ...
# 651929         0.675   0.937   -3525.0        0.051         0.152
# 651930         0.675   0.562   -7678.0        0.035         0.233
# 651933         0.665   0.771   -5779.0        0.053         0.016
# 651934         0.757   0.882   -6125.0        0.248         0.076
# 651935         0.757   0.882   -6125.0        0.248         0.076
#
#         Instrumentalness  ...    Artist (Ind.) # of Nationality  \
# 274                  0.0  ...              IVE    Nationality 1
# 277                  0.0  ...       Hotel Ugly    Nationality 1
# 278                  0.0  ...     Taylor Swift    Nationality 1
# 279                  0.0  ...  Imagine Dragons    Nationality 1
# 280                  0.0  ...       Ed Sheeran    Nationality 1
# ...                  ...  ...              ...              ...
# 651929               0.0  ...            KREAM    Nationality 1
# 651930               0.0  ...      Post Malone    Nationality 1
# 651933               0.0  ...       The Weeknd    Nationality 1
# 651934               0.0  ...            JAY-Z    Nationality 1
# 651935               0.0  ...       Kanye West    Nationality 2
#
#            Nationality      Continent Points (Total)  \
# 274        South Korea           Asia             15
# 277      United States  Anglo-America             12
# 278      United States  Anglo-America             11
# 279      United States  Anglo-America             10
# 280     United Kingdom         Europe              9
# ...                ...            ...            ...
# 651929          Norway         Europe              6
# 651930   United States  Anglo-America              5
# 651933          Canada  Anglo-America              2
# 651934   United States  Anglo-America              1
# 651935   United States  Anglo-America              1
#
#        Points (Ind for each Artist/Nat)                      id  \
# 274                                15.0  70t7Q6AYG6ZgTYmJWcnkUM
# 277                                12.0  3hxIUxnT27p5WcmjGUXNwx
# 278                                11.0  1dGr1c8CrMLDpV6mPbImSI
# 279                                10.0  5qaEfEh1AtSdrdrByCP7qR
# 280                                 9.0  3xWGA8pa0IKFI7IMPri4P0
# ...                                 ...                     ...
# 651929                              6.0  26hcyzSE154xMZCbFdtInA
# 651930                              5.0  6eT7xZZlB2mwyzJ2sUKG6w
# 651933                              2.0  3DX4Y0egvc0slLcLl31h2p
# 651934                              1.0  2KpCpk6HjXXLb7nnXoXA5O
# 651935                              1.0  2KpCpk6HjXXLb7nnXoXA5O
#
#                                                      Song URL Day_in_week  \
# 274     https://open.spotify.com/track/70t7Q6AYG6ZgTYmJWcnkUM      Monday
# 277     https://open.spotify.com/track/3hxIUxnT27p5WcmjGUXNwx      Monday
# 278     https://open.spotify.com/track/1dGr1c8CrMLDpV6mPbImSI      Monday
# 279     https://open.spotify.com/track/5qaEfEh1AtSdrdrByCP7qR      Monday
# 280     https://open.spotify.com/track/3xWGA8pa0IKFI7IMPri4P0      Monday
# ...                                                       ...         ...
# 651929  https://open.spotify.com/track/26hcyzSE154xMZCbFdtInA      Sunday
# 651930  https://open.spotify.com/track/6eT7xZZlB2mwyzJ2sUKG6w      Sunday
# 651933  https://open.spotify.com/track/3DX4Y0egvc0slLcLl31h2p      Sunday
# 651934  https://open.spotify.com/track/2KpCpk6HjXXLb7nnXoXA5O      Sunday
# 651935  https://open.spotify.com/track/2KpCpk6HjXXLb7nnXoXA5O      Sunday
#
#        Month
# 274        5
# 277        5
# 278        5
# 279        5
# 280        5
# ...      ...
# 651929     1
# 651930     1
# 651933     1
# 651934     1
# 651935     1
#
# [31799 rows x 22 columns]

# %%
for cluster in df_cluster["cluster"].unique():
    plt.figure(figsize=(8,4))
    sns.histplot(df.filter(items=df_cluster[df_cluster["cluster"] == cluster].index, axis=0)["Continent"])
    plt.show()
